# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_churn = pd.read_csv(
    "D:\\UNIVERSITY\\ML\\Week02\\ForHome\\Data\\telecom_churn_clean.csv")
y = df_churn['churn']
X_train, X_test, y_train, y_test = train_test_split(df_churn, y, test_size=0.2, random_state=21, stratify=y)

knn = KNeighborsClassifier(n_neighbors=5, metric='manhattan')

# %%
# baseline model
churn_count = sum(y_test)
print(1 - churn_count / len(y_test))
# Out:
# 0.8545727136431784

# %%
# Experiment 1
# international_plan feature

X_train_1 = X_train[['international_plan']]
X_test_1 = X_test[['international_plan']]

knn.fit(X_train_1, y_train)

prediction = knn.predict(X_test_1)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8545727136431784

# %%
# Experiment 2
# voice_mail_plan feature

X_train_2 = X_train[['voice_mail_plan']]
X_test_2 = X_test[['voice_mail_plan']]

knn.fit(X_train_2, y_train)

prediction = knn.predict(X_test_2)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8545727136431784

# %%
# Experiment 3
# number_vmail_messages feature

X_train_3 = X_train[['number_vmail_messages']]
X_test_3 = X_test[['number_vmail_messages']]

knn.fit(X_train_3, y_train)

prediction = knn.predict(X_test_3)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8545727136431784

# %%
# Experiment 4
# total_day_calls feature

X_train_4 = X_train[['total_day_calls']]
X_test_4 = X_test[['total_day_calls']]

knn.fit(X_train_4, y_train)

prediction = knn.predict(X_test_4)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8425787106446777

# %%
# Experiment 5
# total_day_charge feature

X_train_5 = X_train[['total_day_charge']]
X_test_5 = X_test[['total_day_charge']]

knn.fit(X_train_5, y_train)

prediction = knn.predict(X_test_5)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8455772113943029

# %%
# Experiment 6
# total_eve_minutes feature

X_train_6 = X_train[['total_eve_minutes']]
X_test_6 = X_test[['total_eve_minutes']]

knn.fit(X_train_6, y_train)

prediction = knn.predict(X_test_6)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8380809595202399

# %%
# Experiment 7
# customer_service_calls feature

X_train_7 = X_train[['customer_service_calls']]
X_test_7 = X_test[['customer_service_calls']]

knn.fit(X_train_7, y_train)

prediction = knn.predict(X_test_7)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8590704647676162

# %%
# Experiment 8
# total_day_minutes, total_eve_minutes feature

X_train_8 = X_train[['total_day_minutes', 'total_eve_minutes']]
X_test_8 = X_test[['total_day_minutes', 'total_eve_minutes']]

knn.fit(X_train_8, y_train)

prediction = knn.predict(X_test_8)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8665667166416792

# %%
# Experiment 9
# total_eve_calls, total_day_minutes feature

X_train_9 = X_train[['total_eve_calls', 'total_day_minutes']]
X_test_9 = X_test[['total_eve_calls', 'total_day_minutes']]

knn.fit(X_train_9, y_train)

prediction = knn.predict(X_test_9)
print(accuracy_score(y_test, prediction))
# Out:
# 0.848575712143928

# %%
# Experiment 10
# total_eve_charge, total_day_charge feature

X_train_10 = X_train[['total_eve_charge', 'total_day_charge']]
X_test_10 = X_test[['total_eve_charge', 'total_day_charge']]

knn.fit(X_train_10, y_train)

prediction = knn.predict(X_test_10)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8665667166416792

# %%
# Experiment 11
# total_night_minutes, total_day_charge feature

X_train_11 = X_train[['total_night_minutes', 'total_day_charge']]
X_test_11 = X_test[['total_night_minutes', 'total_day_charge']]

knn.fit(X_train_11, y_train)

prediction = knn.predict(X_test_11)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8590704647676162

# %%
# Experiment 12
# customer_service_calls, total_day_charge feature

X_train_12 = X_train[['customer_service_calls', 'total_day_charge']]
X_test_12 = X_test[['customer_service_calls', 'total_day_charge']]

knn.fit(X_train_12, y_train)

prediction = knn.predict(X_test_12)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8695652173913043

# %%
# Experiment 13
# customer_service_calls, total_night_charge feature

X_train_13 = X_train[['customer_service_calls', 'total_night_charge']]
X_test_13 = X_test[['customer_service_calls', 'total_night_charge']]

knn.fit(X_train_13, y_train)

prediction = knn.predict(X_test_13)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8500749625187406

# %%
# Experiment 14
# total_day_charge, total_day_minutes feature

X_train_14 = X_train[['total_day_charge', 'total_day_minutes']]
X_test_14 = X_test[['total_day_charge', 'total_day_minutes']]

knn.fit(X_train_14, y_train)

prediction = knn.predict(X_test_14)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8455772113943029

# %%
# Experiment 15
# total_night_charge, total_day_minutes features

X_train_15 = X_train[['total_night_charge', 'total_day_charge']]
X_test_15 = X_test[['total_night_charge', 'total_day_charge']]

knn.fit(X_train_15, y_train)

prediction = knn.predict(X_test_15)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8575712143928036

# %%
# Experiment 16
# total_intl_charge, total_day_minutes features

X_train_16 = X_train[['total_intl_charge', 'total_day_minutes']]
X_test_16 = X_test[['total_intl_charge', 'total_day_minutes']]

knn.fit(X_train_16, y_train)

prediction = knn.predict(X_test_16)
print(accuracy_score(y_test, prediction))
# Out:
# 0.863568215892054

# %%
# Experiment 17
# total_eve_minutes, total_day_minutes, customer_service_calls features

X_train_17 = X_train[['total_eve_minutes', 'total_day_minutes', 'customer_service_calls']]
X_test_17 = X_test[['total_eve_minutes', 'total_day_minutes', 'customer_service_calls']]

knn.fit(X_train_17, y_train)

prediction = knn.predict(X_test_17)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8710644677661169

# %%
# Experiment 18
# voice_mail_plan, number_vmail_messages features

X_train_18 = X_train[['voice_mail_plan', 'number_vmail_messages']]
X_test_18 = X_test[['voice_mail_plan', 'number_vmail_messages']]

knn.fit(X_train_18, y_train)

prediction = knn.predict(X_test_18)
print(accuracy_score(y_test, prediction))
# Out:
# 0.8545727136431784

# %%
n_neighbors = range(60)
accuracy_scores = []
for i in range(1, 61):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train_17, y_train)
    prediction = knn.predict(X_test_17)
    accuracy_scores.append(accuracy_score(y_test, prediction))

plot = sns.lineplot(x=n_neighbors, y=accuracy_scores, color='blue')
plt.title('Accuracy vs Number of Neighbors for the top model')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.grid(True)
plot.figure.savefig('neighbors_vs_accuracy.png')
